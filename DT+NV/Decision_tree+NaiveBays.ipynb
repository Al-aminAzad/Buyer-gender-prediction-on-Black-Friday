# %%
import pandas as pd
df=pd.read_excel("Data_Set.xlsx")
df
# Out:
#     cylinders  displacement  horsepower  weight  acceleration  modelyear  \
# 0           8           350         150    4699          14.5         74
# 1           8           400         170    4746          12.0         71
# 2           8           400         175    4385          12.0         72
# 3           6           250          72    3158          19.5         75
# 4           8           304         150    3892          12.5         72
# 5           8           350         145    4440          14.0         75
# 6           6           250         105    3897          18.5         75
# 7           6           163         133    3410          15.8         78
# 8           8           260         110    4060          19.0         77
# 9           8           305         130    3840          15.4         79
# 10          6           250         110    3520          16.4         77
# 11          6           258          95    3193          17.8         76
# 12          4           121         112    2933          14.5         72
# 13          6           225         105    3613          16.5         74
# 14          4           121         112    2868          15.5         73
# 15          6           225          95    3264          16.0         75
# 16          6           200          85    2990          18.2         79
# 17          4           121          98    2945          14.5         75
# 18          6           232          90    3085          17.6         76
# 19          4           120          97    2506          14.5         72
# 20          4           151          85    2855          17.6         78
# 21          4           116          75    2158          15.5         73
# 22          4           119          97    2545          17.0         75
# 23          6           146         120    2930          13.8         81
# 24          4           116          81    2220          16.9         76
# 25          4           156          92    2620          14.4         81
# 26          4           140          88    2870          18.1         80
# 27          4            97          60    1834          19.0         71
# 28          4           134          95    2560          14.2         78
# 29          4            97          75    2171          16.0         75
# 30          4            97          78    1940          14.5         77
# 31          4            98          83    2219          16.5         74
# 32          4            79          70    2074          19.5         71
# 33          4            91          68    1970          17.6         82
# 34          4            89          71    1925          14.0         79
# 35          4            83          61    2003          19.0         74
# 36          4           112          88    2395          18.0         82
# 37          4            81          60    1760          16.1         81
# 38          4           135          84    2370          13.0         82
# 39          4           105          63    2125          14.7         82
# 40          4           135          84    2370          13.0         82
# 41          4           105          63    2125          14.7         82
#
#       maker   mpg
# 0   America   Bad
# 1   America   Bad
# 2   America   Bad
# 3   America   Bad
# 4   America   Bad
# 5   America   Bad
# 6   America   Bad
# 7      Asia   Bad
# 8   America   Bad
# 9   America   Bad
# 10  America   Bad
# 11  America   Bad
# 12     Asia   Bad
# 13  America   Bad
# 14     Asia   Bad
# 15  America   Bad
# 16  America   Bad
# 17     Asia    OK
# 18  America    OK
# 19   Europe    OK
# 20  America    OK
# 21     Asia    OK
# 22   Europe    OK
# 23   Europe    OK
# 24     Asia    OK
# 25  America    OK
# 26  America    OK
# 27     Asia    OK
# 28   Europe    OK
# 29   Europe    OK
# 30     Asia    OK
# 31     Asia    OK
# 32     Asia  Good
# 33   Europe  Good
# 34     Asia  Good
# 35   Europe  Good
# 36  America  Good
# 37   Europe  Good
# 38  America  Good
# 39  America  Good
# 40  America   Bad
# 41  America   Bad

# %%
X=df.iloc[:,:-1]
Y=df.iloc[:,7]
mak = pd.get_dummies(df['maker'],drop_first=True)
X = pd.concat([X,mak],axis=1)
X = X.drop('maker',axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=.2,random_state=0)

# %%
from sklearn import tree
algo= tree.DecisionTreeClassifier()
algo.fit(X_train, Y_train)
Y_predict =algo.predict(X_test)
print(Y_predict)
# Out:
# ['Good' 'Bad' 'Good' 'Bad' 'Bad' 'OK' 'OK' 'Bad' 'Good']

# %%
Y_test
# Out:
# 30      OK
# 36    Good
# 27      OK
# 4      Bad
# 10     Bad
# 25      OK
# 28      OK
# 11     Bad
# 37    Good
# Name: mpg, dtype: object

# %%
print("Naive Bayes")
# Out:
# Naive Bayes

# %%
import pandas as pd
df=pd.read_excel("Data_Set.xlsx")

# %%
X=df.iloc[:,:-1]
Y=df.iloc[:,7]
mak = pd.get_dummies(df['maker'],drop_first=True)
X = pd.concat([X,mak],axis=1)
X = X.drop('maker',axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=.2,random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB
algo=GaussianNB()
algo.fit(X_train, Y_train)
Y_predict =algo.predict(X_test)
print(Y_predict)
# Out:
# ['Good' 'Good' 'Good' 'Bad' 'Bad' 'OK' 'OK' 'Bad' 'Good']

# %%
#Y_test
# Out:
# 30      OK
# 36    Good
# 27      OK
# 4      Bad
# 10     Bad
# 25      OK
# 28      OK
# 11     Bad
# 37    Good
# Name: mpg, dtype: object
